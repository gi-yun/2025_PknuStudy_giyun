# %% [markdown]
# # 시각화 모듈 시본 Seaborn (팁문화분석)

# %%
# !pip install seaborn
# !pip install matplotlib.pyplt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplt (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplt

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# OS에 사용가능한, 설치된 폰트를 나열
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.font_manager as fm
# fontlist = fm.findSystemFonts(fontpaths=None, fontext='ttf')
# fontlist
plt.rc('font', family="NanumBarunGothic")
plt.text(0.2,0.4,'한글', size=100)
# Out:
# Text(0.2, 0.4, '한글')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')
fig = plt.figure(figsize=(15,5))

ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.stripplot(x='day', y='tip',hue='sex',data=tips, alpha = 0.7, ax=ax1)
sns.swarmplot(x='day',y='tip',hue='sex',data=tips, palette='Set2',alpha=0.7,ax=ax2)
ax1.set_title('Strip plot으로 표현한 날짜와 성별과의 팁관계')
ax2.set_title('Swarm plot으로 표현한 날짜와 성별과의 팁관계')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')
fig = plt.figure(figsize=(15,5))

ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.countplot(x='time', data=tips, ax=ax1)
sns.countplot(x='day', hue='day',data=tips ,palette='Set2',ax=ax2)
ax1.set_title('countplot plot으로 시간에 따른 팁빈도')
ax2.set_title('countplot plot으로 시간과 날짜에 따른 팁빈도')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')

fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.regplot(x='total_bill', y='tip', data=tips, color='blue', scatter_kws={"s":50,"alpha":0.5}, line_kws={"linestyle":"--"}, ax=ax1)
sns.regplot(x='total_bill', y='tip', data=tips, color='blue', scatter_kws={"s":50,"alpha":0.5}, fit_reg=False, ax=ax2)

fig.suptitle("Scatter plots 선형회귀 의 On Off 비교")
ax1.set_title('선형회귀 ON')
ax2.set_title('선형회귀 OFF')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
iris = sns.load_dataset('iris')

sns.pairplot(iris, hue='species',markers=["o","s","D"])

plt.show()

# %%
sns.boxplot(x='species',y='sepal_length',data=iris)
plt.title("꽃받침 길이와 종의 관계")
plt.show()

# %%
sns.violinplot(x="species", y="petal_length",data=iris, hue="species",palette="muted")
plt.title("종에 꽃잎의 길이 분포")
plt.show()

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.boxplot(x='species',y='sepal_length',data=iris, ax=ax1)
sns.violinplot(x="species", y="petal_length",data=iris, hue="species",palette="muted", ax=ax2)

ax1.set_title("꽃받침 길이와 종의 관계")
ax2.set_title("종에 꽃잎의 길이 분포")

plt.show()

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)
# ax4 = fig.add_subplot(1,3,)

sns.boxplot(x='species',y='sepal_length',data=iris, ax=ax1)
sns.violinplot(x="species", y="petal_length",data=iris, hue="species",palette="muted", ax=ax2)
sns.histplot(data=iris, x="petal_length", hue="species", kde=True, element="step", palette="Set2",ax=ax3)


ax1.set_title("꽃받침 길이와 종의 관계")
ax2.set_title("종에 따른 꽃잎의 길이 분포1")
ax3.set_title("종에 따른 꽃잎의 길이분포2")
sns.lmplot(x="sepal_length",y="sepal_width", hue="species", data=iris, markers=["o","s","D"],height=6, aspect=1.2)
plt.title("꼬찯침 길이와 너비의 관계")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
exercise = sns.load_dataset('exercise')
exercise.sample(5)
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 29          29  10   no fat    100  30 min     rest
# 65          65  22  low fat    112  30 min  running
# 62          62  21  low fat    110  30 min  running
# 6            6   3  low fat     97   1 min     rest
# 45          45  16   no fat     84   1 min  walking

# %%
#point plot
plt.figure(figsize=(10,6))
sns.pointplot(x='time',y='pulse',hue='kind',data=exercise,capsize=0.1)
plt.title("심박수와 시간별 운동종류와의 관계")
# Out:
# Text(0.5, 1.0, '심박수와 시간별 운동종류와의 관계')

# %%
# box plot
plt.figure(figsize=(7,4))
sns.boxplot(x='time', y='pulse', hue="kind",data= exercise, palette="Set2")
plt.title("심박수와 시간별 운동종류와의 관계")
# Out:
# Text(0.5, 1.0, '심박수와 시간별 운동종류와의 관계')

# %%
# swarm plot
plt.figure(figsize=(7,4))
sns.swarmplot(x='time', y='pulse', hue="kind",data= exercise, dodge=True, palette="Set1" )
plt.title("시간과 운동 유형에 따른 개별 맥박 측정")
plt.show()

# %% [markdown]
# 종합 결론 고강도 운동(Running): 시간이 지날수록 심박수가 급격히 상승하며 변동성이 커집니다. 저강도 운동(Walking): 심박수는 서서히 증가하지만 변동성이 크지는 않습니다. 휴식(Rest): 심박수는 거의 일정하게 유지되며 안정적입니다. 실무적 적용: 이러한 시각화는 운동 강도에 따른 심박수의 변화를 명확히 보여주어, 운동 처방 또는 심박수 기반 피트니스 프로그램 설계에 유용할 수 있습니다.
