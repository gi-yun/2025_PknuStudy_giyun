# %% [markdown]
# # 샘플링 해오기

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (2.2.2)
# Requirement already satisfied: pillow in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.4-cp313-cp313-win_amd64.whl (300 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from konlpy.tag import Komoran # 명사만 분리하기

# 샘플 텍스트
text = """
When G.D’s in the house (Übermensch)
When G.D’s in the house
Guess who’s back (It’s ur boy G.D)

Now I got the power, The power power up power power
The power up power power yet, yet
억까 짤 퍼다 샬라샬라하다가 shout out
Pump up the power 난 자유로워 yap, yap
Do not waste your time yea it’s gotta be me
Prove ‘em all wrong I’ve got all the receipts
I got the power the power power up power
나는 나다워서 아름다워 yep, yep

애들이 나보고 개꿀이라더군
댓글 리플 관종 걔들 입틀막고
2세대 한정품이 세기의 완성품
(Like a Dragon fly) 누울 자리 글로 발명품

Hi-Hey-How u doin’ My-my name is (Called)
G to the D or ‘GOAT’ the livin’ legend
King is still poppin’ (star) ’K‘- 다시
I heard you’ve got the straight flush (Whateva) “He’s 4ever royal.”

I don’t give a 쉬-잇 웃다 끝 ‘돈’ 기부 ‘억’ 씨-익
권력오남용 묻고 관용 천재 지병 불가항력
Way too strong I’ve got that

Now I got the power, The power power up power power
The power up power power yet, yet
억까 짤 퍼다 샬라샬라하다가 shout out
Pump up the power 난 자유로워 yap, yap
Do not waste your time yea it’s gotta be me
Prove ‘em all wrong I’ve got all the receipts
I got the power the power power up power
나는 나다워서 아름다워 yep, yep

일당백 ‘지뢰밭’ 본업이(Born to be) ‘BANG’ Nothin’ U ain’t know But A ‘G’ Thang
But my girl, Y’all my brothers (Who run the world?) The world is yours
동서남북 Asia (미르시여) Europe to Australia (나르샤) Africa 2 America (어서옵쇼)
Started from the bottom ‘Now, Here’ (아리랑)

I don’t give a 쉬-잇 웃다 끝 ‘돈’ 기부 ‘억’ 씨-익
권력오남용 묻고 관용 천재 지병 불가항력
Way too strong I’ve got that

Now I got the power, The power power up power power
The power up power power yet, yet
억까 짤 퍼다 샬라샬라하다가 shout out
Pump up the power 난 자유로워 yap, yap
Do not waste your time yea it’s gotta be me
Prove ‘em all wrong I’ve got all the receipts
I got the power the power power up power
나는 나다워서 아름다워 yep, yep

I got the power the power power, “88 날아.”



"""
komoran = Komoran()
nouns = komoran.nouns(text)
nouns_text = " ".join(nouns)
print(nouns_text)


# 워드 클라우드
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis('off') #그림을 화면에 표시
plt.show()

word_counts = Counter(nouns_text.split())
print(word_counts)
# Out:
# 까 퍼다 자유 애 개 꿀 댓글 리플 관 종 입 틀 세대 한정 품 세기 완성품 자리 글 발명품 잇 끝 돈 기부 씨 익 권력 오남용 관용 천재 지병 불가항력 까 퍼다 자유 일당 백 지뢰밭 본업 이 동서남북 미르 시 나르샤 아리랑 잇 끝 돈 기부 씨 익 권력 오남용 관용 천재 지병 불가항력 까 퍼다 자유
# Counter({'까': 3, '퍼다': 3, '자유': 3, '잇': 2, '끝': 2, '돈': 2, '기부': 2, '씨': 2, '익': 2, '권력': 2, '오남용': 2, '관용': 2, '천재': 2, '지병': 2, '불가항력': 2, '애': 1, '개': 1, '꿀': 1, '댓글': 1, '리플': 1, '관': 1, '종': 1, '입': 1, '틀': 1, '세대': 1, '한정': 1, '품': 1, '세기': 1, '완성품': 1, '자리': 1, '글': 1, '발명품': 1, '일당': 1, '백': 1, '지뢰밭': 1, '본업': 1, '이': 1, '동서남북': 1, '미르': 1, '시': 1, '나르샤': 1, '아리랑': 1})

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import matplotlib.font_manager as fm
from konlpy.tag import Komoran # 명사만 분리하기


#한글 폰트 설정
font_path = "./ref/D2Coding-Ver1.3.2-20180524.ttf"



# 샘플 텍스트
text = """

헌릉에 거둥하여 삭제를 행하다
기우제에 쓸 향과 축문을 전하다
대사헌 하연 등이 경녕군의 처벌을 상소하다
무녀를 모아 비를 빌게 하다
병조에서 사금과 충의위·별시위의 번에 대해 건의하다
정사를 보다
종묘에서 비를 빌다
기우제에 쓸 향과 축문을 전하다
임금이 가뭄의 재앙으로 금주를 실행하다
지평 조극관이 경녕군의 처벌을 상소하다
일본 중 원재에게 옷을 하사하다
가뭄으로 도살을 금지하다
원평 부사 윤구의 유배를 면하여 외방에 부처케 하다
밤에 비가 내리다
영의정이 임금에게 술의 복약을 건의했으나 윤허하지 아니하다
황해·강원·평안도에 환관 파견하여 수령의 구제상황을 살피게 하다
사직에서 비를 빌다
단오 별제에 쓸 향과 축문을 전하다
양녕 대군을 헌릉 소상제에 참여토록 하다
저자를 옮기다
예조에서 사내의 승도와 무녀에게 비를 빌게할 것 건의하다
비가 내리다
찬성 유관 등이 임금에게 술로 복약할 것을 건의했으나 윤허치 아니하다
세면포 등을 대자암에 보내다
예조에서 태종 공정대왕의 연제의주에 대해 아뢰다
태종 소상 기신재에 쓸 향과 축문을 전하다
연관을 양녕 대군에 전하다
태종 대왕 소상 기신재를 진관사에서 거행하다
임금이 광효전에서 소상제를 거행하다
정사를 보다
우사간이 경녕군을 법대로 처형토록 상소하다
전라도에 환상미곡을 추가 지급하다
사헌부에서 국상기간에 술 마신 이등·홍해 옹주의 처벌을 아뢰다
사헌부에서 총제 정효문의 처벌을 아뢰다
정부·육조에서 육선 진어를 청하였으나 허락치 아니하다
순덕후 진이의 처에게 곡식을 내려주다
정사를 보다
태인 양잠감고 이효순을 역승에 임명하다
예조에서 문무관의 휴가에 대해 건의하다
전라도 감사가 큰비가 내린 관계로 기우의 중지를 청하다
예조에서 투화자에 대한 의복하사법의 제정을 건의하다
전라도 감사가 익사 선군에게 부의할 것을 아뢰다
경기 적성현 박인부가 벼락맞다
광효전에서 망제를 행하다
정사를 보다
전 부령 유강생을 외방에 부처하다
병조에서 전 부사직의 처벌을 아뢰다
예조에서 잡과를 시험보다
정사를 보다
예조에서 기우에 사용하는 예기에 대해 건의하다
경기·충청도 감사가 비가 내린 사실을 보고하다
예조에서 직 받은 동소라 등에게 노비 하사를 청하다
경연에 나가다
좌의정 이원 등이 임금에게 육선 진어를 청하다
인재 등용에 관한 사헌부의 상소문
잡과의 방을 발표하다
정사를 보다
함길도 감사가 요청한 유리 기민의 구제미를 지급케 하다
호조에서 오부의 인민에게 환상미 추가 지급을 청하다
평안도 감사가 비내린 사실을 보고하다
함길도 감사가 길주의 산성창고의 화재를 보고하다
각품에 대해 녹 주는 것을 의정부와 육조에서 의논케 하다
정사를 보다
강원도 감사가 비내린 사실을 보고하다
일본국 관서도 원준신이 토산물을 바치다
정사를 보다
지평 조극관이 경녕군 처벌을 아뢰다
황해도 감사가 비내린 사실을 보고하다
비가 내리다
정사를 보다
대사헌 하연 등이 경녕군의 범죄에 대해 핵론하다
경기우도 각 목장의 자웅마중 금년에 증가한 말이 288필로 집계하다
도적질한 노비 동을구리를 처벌하다
정사를 보다
경외 관리의 임기 개월수를 의논케 하다
충청도 감사가 선군·관사의 노비 등이 유망하는 폐단에 대해 건의하다
병조에서 염초 사적 사용을 엄금케 하다
호조에서 기민의 구제책을 건의하다
구주 도원수 원의준이 토산물을 바치다
축주부 석성관사 평만경이 토산물을 바치다
작주 전 자사 평상가가 토산물을 바치다
구주 전 총관 원도진이 토산물을 바치다
비가 내리다
경연에 나가다
이조에서 각진의 병마사 임명에 대해 건의하다
익사한 광주 선군에게 부의케 하다
경상도 감사가 안비현에 대해 비안현으로 할 것을 건의하여 따르다
권현·김구덕·황희·김여지·이징 등에게 관직을 제수하다
환관 김수를 의금부에 가두게 하다
성균 박사 박서·교서랑 곽규 등을 의금부에 가두다
정사를 보다
진상품 부과 각도 감사와 수령이 지킬 조령·녹봉의 폐단·세금과 부역 등에 관한 진언문
예조에서 태종 공정 대왕의 제사에 관해 아뢰다
정사를 보다
전 전주 부윤 신극공의 졸기
삭제에 쓸 향과 축문을 전하다
의금부에서 김수의 처벌을 아뢰다


"""

# data = [t for t in text if bool(t.strip())]
# print(data)

komoran = Komoran()
nouns = komoran.nouns(text)
nouns_text = " ".join(nouns)
print(nouns_text)












# 워드 클라우드
wordcloud = WordCloud(font_path=font_path,width=800, height=400, background_color='white').generate(nouns_text)

# 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis('off') # x,y 축 없애기
# plt.savefig("word") # 사진으로 만들기
plt.show()

word_counts = Counter(nouns_text.split())
print(word_counts)
# Out:
# 헌릉 거 둥 삭제 기우제 향 축문 대사헌 하연 등 경녕군 처벌 상소 무녀 모아 비 병조 사 금 충의위 별시위 번 건의 정사 종묘 비 기우제 향 축문 임금 가뭄 재앙 금주 실행 지평 조극관 경녕군 처벌 상소 일본 중 원재 옷 하사 가뭄 도살 금지 원평 부사 윤구 유배 면 외방 부처 밤 비 영의정 임금 술 복약 건의 윤허 황해 강원 평안도 환관 파견 수령 구제 상황 사직 비 단오 별 향 축문 대군 헌릉 상제 참여 저자 예조 사내 승도 무녀 비 것 건의 비 찬성 유관 등 임금 술 복약 것 건의 윤허 세면 포 등 대자암 예조 태종 공정대왕 연제 의주 태종 소상 기신 재 향 축문 연관 대군 태종 대왕 소상 기신 재 진관사 거행 임금 광 효 전 상제 거행 정사 우사 간 경녕군 법 처형 상소 전라도 환상 미곡 추가 지급 사헌부 국상 기간 술 이등 홍해 옹주 처벌 사헌부 총 정효 문 처벌 정부 육조 육서 진어 허락 순덕 후 이 처 곡식 정사 태인 양잠 이효수 역 승 임명 예조 문무관 휴가 건의 전라도 감사 큰비 관계 기우 중지 예조 투 화자 의복 하사 법 제정 건의 전라도 감사 익사 선 군 부의 것 경기 적 성현 박 인부 벼락 광 효 전 망 정사 유강 외방 부처 병조 사직 처벌 예조 잡과 시험 정사 예조 기우 사용 예기 건의 경기 충청도 감사 비 사실 보고 예조 직 소라 등 노비 하사 경연 좌의정 이원 등 임금 육서 진어 인재 등용 사헌부 상소문 잡과 방 발표 정사 함 길 감사 요청 유리 기민 구제 미 지급 호조 오부 인민 환상 미 추가 지급 평안도 감사 내리 사실 보고 함 길 감사 길 주의 산성 창고 화재 보고 품 녹 것 의정부 육조 의논 정사 강원도 감사 내리 사실 보고 일본국 관서 원준 신이 토산물 정사 지평 조극관 경녕군 처벌 황해도 감사 내리 사실 보고 비 정사 대사헌 하연 등 경녕군 범죄 핵 경기 우도 목장 자웅 마중 금년 증가 말 필 집계 도적 노비 동 을 구리 처벌 정사 경외 관리 임기 개월 수 의논 충청도 감 사가 선 군 관사 노비 등 유망 폐단 건의 병조 염 초 사적 사용 엄금 호조 기민 구제 책 건의 구주 도원수 원 의주 토산물 축 주부 석성 관사 평 만 토산물 작주 자사 평 상가 토산물 구주 총 원도 진 토산물 비 경연 이조 진 병마사 임명 건의 익사 한 광주 선 군 부의 경상도 감사 안비 현 안 현 것 건의 권 현 김구덕 황희 김 여지 이징 등 관직 제수 환관 김수 의금부 성 균 박사 박 교서 곽 규 등 의금부 정사 상품 부과 각도 감사 수령 조령 녹봉 폐단 세금 부역 등 진언 문 예조 태종 공정 대왕 제사 정사 전주 부윤 신극 공 삭제 향 축문 의금부 김수 처벌

# %%
from collections import Counter
word_counts = Counter(nouns_text.split())
print(word_counts)
# Out:
# Counter({'정사': 12, '건의': 11, '등': 10, '감사': 10, '비': 9, '처벌': 8, '예조': 8, '향': 5, '축문': 5, '경녕군': 5, '임금': 5, '것': 5, '보고': 5, '토산물': 5, '태종': 4, '사실': 4, '상소': 3, '병조': 3, '하사': 3, '술': 3, '구제': 3, '전라도': 3, '지급': 3, '사헌부': 3, '선': 3, '군': 3, '경기': 3, '노비': 3, '길': 3, '내리': 3, '현': 3, '의금부': 3, '헌릉': 2, '삭제': 2, '기우제': 2, '대사헌': 2, '하연': 2, '무녀': 2, '가뭄': 2, '지평': 2, '조극관': 2, '외방': 2, '부처': 2, '복약': 2, '윤허': 2, '평안도': 2, '환관': 2, '수령': 2, '사직': 2, '대군': 2, '상제': 2, '의주': 2, '소상': 2, '기신': 2, '재': 2, '대왕': 2, '거행': 2, '광': 2, '효': 2, '전': 2, '법': 2, '환상': 2, '추가': 2, '총': 2, '문': 2, '육조': 2, '육서': 2, '진어': 2, '임명': 2, '기우': 2, '익사': 2, '부의': 2, '박': 2, '잡과': 2, '사용': 2, '충청도': 2, '경연': 2, '함': 2, '기민': 2, '미': 2, '호조': 2, '의논': 2, '관사': 2, '폐단': 2, '구주': 2, '평': 2, '진': 2, '김수': 2, '거': 1, '둥': 1, '모아': 1, '사': 1, '금': 1, '충의위': 1, '별시위': 1, '번': 1, '종묘': 1, '재앙': 1, '금주': 1, '실행': 1, '일본': 1, '중': 1, '원재': 1, '옷': 1, '도살': 1, '금지': 1, '원평': 1, '부사': 1, '윤구': 1, '유배': 1, '면': 1, '밤': 1, '영의정': 1, '황해': 1, '강원': 1, '파견': 1, '상황': 1, '단오': 1, '별': 1, '참여': 1, '저자': 1, '사내': 1, '승도': 1, '찬성': 1, '유관': 1, '세면': 1, '포': 1, '대자암': 1, '공정대왕': 1, '연제': 1, '연관': 1, '진관사': 1, '우사': 1, '간': 1, '처형': 1, '미곡': 1, '국상': 1, '기간': 1, '이등': 1, '홍해': 1, '옹주': 1, '정효': 1, '정부': 1, '허락': 1, '순덕': 1, '후': 1, '이': 1, '처': 1, '곡식': 1, '태인': 1, '양잠': 1, '이효수': 1, '역': 1, '승': 1, '문무관': 1, '휴가': 1, '큰비': 1, '관계': 1, '중지': 1, '투': 1, '화자': 1, '의복': 1, '제정': 1, '적': 1, '성현': 1, '인부': 1, '벼락': 1, '망': 1, '유강': 1, '시험': 1, '예기': 1, '직': 1, '소라': 1, '좌의정': 1, '이원': 1, '인재': 1, '등용': 1, '상소문': 1, '방': 1, '발표': 1, '요청': 1, '유리': 1, '오부': 1, '인민': 1, '주의': 1, '산성': 1, '창고': 1, '화재': 1, '품': 1, '녹': 1, '의정부': 1, '강원도': 1, '일본국': 1, '관서': 1, '원준': 1, '신이': 1, '황해도': 1, '범죄': 1, '핵': 1, '우도': 1, '목장': 1, '자웅': 1, '마중': 1, '금년': 1, '증가': 1, '말': 1, '필': 1, '집계': 1, '도적': 1, '동': 1, '을': 1, '구리': 1, '경외': 1, '관리': 1, '임기': 1, '개월': 1, '수': 1, '감': 1, '사가': 1, '유망': 1, '염': 1, '초': 1, '사적': 1, '엄금': 1, '책': 1, '도원수': 1, '원': 1, '축': 1, '주부': 1, '석성': 1, '만': 1, '작주': 1, '자사': 1, '상가': 1, '원도': 1, '이조': 1, '병마사': 1, '한': 1, '광주': 1, '경상도': 1, '안비': 1, '안': 1, '권': 1, '김구덕': 1, '황희': 1, '김': 1, '여지': 1, '이징': 1, '관직': 1, '제수': 1, '성': 1, '균': 1, '박사': 1, '교서': 1, '곽': 1, '규': 1, '상품': 1, '부과': 1, '각도': 1, '조령': 1, '녹봉': 1, '세금': 1, '부역': 1, '진언': 1, '공정': 1, '제사': 1, '전주': 1, '부윤': 1, '신극': 1, '공': 1})

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import matplotlib.font_manager as fm
from konlpy.tag import Komoran # 명사만 분리하기
from collections import Counter

#한글 폰트 설정
font_path = "./ref/D2Coding-Ver1.3.2-20180524.ttf"



# 샘플 텍스트
text = """

When G.D’s in the house (Übermensch)
When G.D’s in the house
Guess who’s back (It’s ur boy G.D)

Now I got the power, The power power up power power
The power up power power yet, yet
억까 짤 퍼다 샬라샬라하다가 shout out
Pump up the power 난 자유로워 yap, yap
Do not waste your time yea it’s gotta be me
Prove ‘em all wrong I’ve got all the receipts
I got the power the power power up power
나는 나다워서 아름다워 yep, yep

애들이 나보고 개꿀이라더군
댓글 리플 관종 걔들 입틀막고
2세대 한정품이 세기의 완성품
(Like a Dragon fly) 누울 자리 글로 발명품

Hi-Hey-How u doin’ My-my name is (Called)
G to the D or ‘GOAT’ the livin’ legend
King is still poppin’ (star) ’K‘- 다시
I heard you’ve got the straight flush (Whateva) “He’s 4ever royal.”

I don’t give a 쉬-잇 웃다 끝 ‘돈’ 기부 ‘억’ 씨-익
권력오남용 묻고 관용 천재 지병 불가항력
Way too strong I’ve got that

Now I got the power, The power power up power power
The power up power power yet, yet
억까 짤 퍼다 샬라샬라하다가 shout out
Pump up the power 난 자유로워 yap, yap
Do not waste your time yea it’s gotta be me
Prove ‘em all wrong I’ve got all the receipts
I got the power the power power up power
나는 나다워서 아름다워 yep, yep

일당백 ‘지뢰밭’ 본업이(Born to be) ‘BANG’ Nothin’ U ain’t know But A ‘G’ Thang
But my girl, Y’all my brothers (Who run the world?) The world is yours
동서남북 Asia (미르시여) Europe to Australia (나르샤) Africa 2 America (어서옵쇼)
Started from the bottom ‘Now, Here’ (아리랑)

I don’t give a 쉬-잇 웃다 끝 ‘돈’ 기부 ‘억’ 씨-익
권력오남용 묻고 관용 천재 지병 불가항력
Way too strong I’ve got that

Now I got the power, The power power up power power
The power up power power yet, yet
억까 짤 퍼다 샬라샬라하다가 shout out
Pump up the power 난 자유로워 yap, yap
Do not waste your time yea it’s gotta be me
Prove ‘em all wrong I’ve got all the receipts
I got the power the power power up power
나는 나다워서 아름다워 yep, yep

I got the power the power power, “88 날아.”


"""

# data = [t for t in text if bool(t.strip())]
# print(data)

komoran = Komoran()
nouns = komoran.nouns(text)
nouns_text = " ".join(nouns)
print(nouns_text)












# 워드 클라우드
wordcloud = WordCloud(font_path=font_path,width=800, height=400, background_color='white').generate(text)

# 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
# plt.axis('off') # x,y 축 없애기
# plt.savefig("word") # 사진으로 만들기
plt.show()



word_counts = Counter(text.split())
print(word_counts)
# Out:
# 까 퍼다 자유 애 개 꿀 댓글 리플 관 종 입 틀 세대 한정 품 세기 완성품 자리 글 발명품 잇 끝 돈 기부 씨 익 권력 오남용 관용 천재 지병 불가항력 까 퍼다 자유 일당 백 지뢰밭 본업 이 동서남북 미르 시 나르샤 아리랑 잇 끝 돈 기부 씨 익 권력 오남용 관용 천재 지병 불가항력 까 퍼다 자유
# Counter({'power': 38, 'the': 24, 'got': 13, 'up': 12, 'I': 10, 'The': 7, 'all': 6, 'I’ve': 5, 'power,': 4, 'Now': 3, 'yet,': 3, 'yet': 3, '억까': 3, '짤': 3, '퍼다': 3, '샬라샬라하다가': 3, 'shout': 3, 'out': 3, 'Pump': 3, '난': 3, '자유로워': 3, 'yap,': 3, 'yap': 3, 'Do': 3, 'not': 3, 'waste': 3, 'your': 3, 'time': 3, 'yea': 3, 'it’s': 3, 'gotta': 3, 'be': 3, 'me': 3, 'Prove': 3, '‘em': 3, 'wrong': 3, 'receipts': 3, '나는': 3, '나다워서': 3, '아름다워': 3, 'yep,': 3, 'yep': 3, 'a': 3, 'is': 3, 'to': 3, 'When': 2, 'G.D’s': 2, 'in': 2, 'house': 2, 'don’t': 2, 'give': 2, '쉬-잇': 2, '웃다': 2, '끝': 2, '‘돈’': 2, '기부': 2, '‘억’': 2, '씨-익': 2, '권력오남용': 2, '묻고': 2, '관용': 2, '천재': 2, '지병': 2, '불가항력': 2, 'Way': 2, 'too': 2, 'strong': 2, 'that': 2, 'But': 2, 'my': 2, '(Übermensch)': 1, 'Guess': 1, 'who’s': 1, 'back': 1, '(It’s': 1, 'ur': 1, 'boy': 1, 'G.D)': 1, '애들이': 1, '나보고': 1, '개꿀이라더군': 1, '댓글': 1, '리플': 1, '관종': 1, '걔들': 1, '입틀막고': 1, '2세대': 1, '한정품이': 1, '세기의': 1, '완성품': 1, '(Like': 1, 'Dragon': 1, 'fly)': 1, '누울': 1, '자리': 1, '글로': 1, '발명품': 1, 'Hi-Hey-How': 1, 'u': 1, 'doin’': 1, 'My-my': 1, 'name': 1, '(Called)': 1, 'G': 1, 'D': 1, 'or': 1, '‘GOAT’': 1, 'livin’': 1, 'legend': 1, 'King': 1, 'still': 1, 'poppin’': 1, '(star)': 1, '’K‘-': 1, '다시': 1, 'heard': 1, 'you’ve': 1, 'straight': 1, 'flush': 1, '(Whateva)': 1, '“He’s': 1, '4ever': 1, 'royal.”': 1, '일당백': 1, '‘지뢰밭’': 1, '본업이(Born': 1, 'be)': 1, '‘BANG’': 1, 'Nothin’': 1, 'U': 1, 'ain’t': 1, 'know': 1, 'A': 1, '‘G’': 1, 'Thang': 1, 'girl,': 1, 'Y’all': 1, 'brothers': 1, '(Who': 1, 'run': 1, 'world?)': 1, 'world': 1, 'yours': 1, '동서남북': 1, 'Asia': 1, '(미르시여)': 1, 'Europe': 1, 'Australia': 1, '(나르샤)': 1, 'Africa': 1, '2': 1, 'America': 1, '(어서옵쇼)': 1, 'Started': 1, 'from': 1, 'bottom': 1, '‘Now,': 1, 'Here’': 1, '(아리랑)': 1, '“88': 1, '날아.”': 1})

# %%
test = ['안녕', '하세요', '안녕','할까요','안녕','하세요']






for i in test :
    count=0
    num =0
    while num<len(test):
        if test[num]==i:
            count+=1
        num+=1
    print(i, count)
# Out:
# 안녕 3
# 하세요 2
# 안녕 3
# 할까요 1
# 안녕 3
# 하세요 2

# %%
from konlpy.tag import Komoran # 명사만 분리하기
from collections import Counter

text = """

When G.D’s in the house (Übermensch)
When G.D’s in the house
Guess who’s back (It’s ur boy G.D)

Now I got the power, The power power up power power
The power up power power yet, yet
억까 짤 퍼다 샬라샬라하다가 shout out
Pump up the power 난 자유로워 yap, yap
Do not waste your time yea it’s gotta be me
Prove ‘em all wrong I’ve got all the receipts
I got the power the power power up power
나는 나다워서 아름다워 yep, yep

애들이 나보고 개꿀이라더군
댓글 리플 관종 걔들 입틀막고
2세대 한정품이 세기의 완성품
(Like a Dragon fly) 누울 자리 글로 발명품

Hi-Hey-How u doin’ My-my name is (Called)
G to the D or ‘GOAT’ the livin’ legend
King is still poppin’ (star) ’K‘- 다시
I heard you’ve got the straight flush (Whateva) “He’s 4ever royal.”

I don’t give a 쉬-잇 웃다 끝 ‘돈’ 기부 ‘억’ 씨-익
권력오남용 묻고 관용 천재 지병 불가항력
Way too strong I’ve got that

Now I got the power, The power power up power power
The power up power power yet, yet
억까 짤 퍼다 샬라샬라하다가 shout out
Pump up the power 난 자유로워 yap, yap
Do not waste your time yea it’s gotta be me
Prove ‘em all wrong I’ve got all the receipts
I got the power the power power up power
나는 나다워서 아름다워 yep, yep

일당백 ‘지뢰밭’ 본업이(Born to be) ‘BANG’ Nothin’ U ain’t know But A ‘G’ Thang
But my girl, Y’all my brothers (Who run the world?) The world is yours
동서남북 Asia (미르시여) Europe to Australia (나르샤) Africa 2 America (어서옵쇼)
Started from the bottom ‘Now, Here’ (아리랑)

I don’t give a 쉬-잇 웃다 끝 ‘돈’ 기부 ‘억’ 씨-익
권력오남용 묻고 관용 천재 지병 불가항력
Way too strong I’ve got that

Now I got the power, The power power up power power
The power up power power yet, yet
억까 짤 퍼다 샬라샬라하다가 shout out
Pump up the power 난 자유로워 yap, yap
Do not waste your time yea it’s gotta be me
Prove ‘em all wrong I’ve got all the receipts
I got the power the power power up power
나는 나다워서 아름다워 yep, yep

I got the power the power power, “88 날아.”


"""
komoran = Komoran()
nouns = komoran.nouns(text)
nouns_text = " ".join(nouns)

word_counts = Counter(text.split())
test_counts = text.split()
print(word_counts)


for i in test_counts :
    count=0
    num =0
    while num<len(test_counts):
        if test_counts[num]==i:
            count+=1
        num+=1
    print(i, count)
# Out:
# Counter({'power': 38, 'the': 24, 'got': 13, 'up': 12, 'I': 10, 'The': 7, 'all': 6, 'I’ve': 5, 'power,': 4, 'Now': 3, 'yet,': 3, 'yet': 3, '억까': 3, '짤': 3, '퍼다': 3, '샬라샬라하다가': 3, 'shout': 3, 'out': 3, 'Pump': 3, '난': 3, '자유로워': 3, 'yap,': 3, 'yap': 3, 'Do': 3, 'not': 3, 'waste': 3, 'your': 3, 'time': 3, 'yea': 3, 'it’s': 3, 'gotta': 3, 'be': 3, 'me': 3, 'Prove': 3, '‘em': 3, 'wrong': 3, 'receipts': 3, '나는': 3, '나다워서': 3, '아름다워': 3, 'yep,': 3, 'yep': 3, 'a': 3, 'is': 3, 'to': 3, 'When': 2, 'G.D’s': 2, 'in': 2, 'house': 2, 'don’t': 2, 'give': 2, '쉬-잇': 2, '웃다': 2, '끝': 2, '‘돈’': 2, '기부': 2, '‘억’': 2, '씨-익': 2, '권력오남용': 2, '묻고': 2, '관용': 2, '천재': 2, '지병': 2, '불가항력': 2, 'Way': 2, 'too': 2, 'strong': 2, 'that': 2, 'But': 2, 'my': 2, '(Übermensch)': 1, 'Guess': 1, 'who’s': 1, 'back': 1, '(It’s': 1, 'ur': 1, 'boy': 1, 'G.D)': 1, '애들이': 1, '나보고': 1, '개꿀이라더군': 1, '댓글': 1, '리플': 1, '관종': 1, '걔들': 1, '입틀막고': 1, '2세대': 1, '한정품이': 1, '세기의': 1, '완성품': 1, '(Like': 1, 'Dragon': 1, 'fly)': 1, '누울': 1, '자리': 1, '글로': 1, '발명품': 1, 'Hi-Hey-How': 1, 'u': 1, 'doin’': 1, 'My-my': 1, 'name': 1, '(Called)': 1, 'G': 1, 'D': 1, 'or': 1, '‘GOAT’': 1, 'livin’': 1, 'legend': 1, 'King': 1, 'still': 1, 'poppin’': 1, '(star)': 1, '’K‘-': 1, '다시': 1, 'heard': 1, 'you’ve': 1, 'straight': 1, 'flush': 1, '(Whateva)': 1, '“He’s': 1, '4ever': 1, 'royal.”': 1, '일당백': 1, '‘지뢰밭’': 1, '본업이(Born': 1, 'be)': 1, '‘BANG’': 1, 'Nothin’': 1, 'U': 1, 'ain’t': 1, 'know': 1, 'A': 1, '‘G’': 1, 'Thang': 1, 'girl,': 1, 'Y’all': 1, 'brothers': 1, '(Who': 1, 'run': 1, 'world?)': 1, 'world': 1, 'yours': 1, '동서남북': 1, 'Asia': 1, '(미르시여)': 1, 'Europe': 1, 'Australia': 1, '(나르샤)': 1, 'Africa': 1, '2': 1, 'America': 1, '(어서옵쇼)': 1, 'Started': 1, 'from': 1, 'bottom': 1, '‘Now,': 1, 'Here’': 1, '(아리랑)': 1, '“88': 1, '날아.”': 1})
# When 2
# G.D’s 2
# in 2
# the 24
# house 2
# (Übermensch) 1
# When 2
# G.D’s 2
# in 2
# the 24
# house 2
# Guess 1
# who’s 1
# back 1
# (It’s 1
# ur 1
# boy 1
# G.D) 1
# Now 3
# I 10
# got 13
# the 24
# power, 4
# The 7
# power 38
# power 38
# up 12
# power 38
# power 38
# The 7
# power 38
# up 12
# power 38
# power 38
# yet, 3
# yet 3
# 억까 3
# 짤 3
# 퍼다 3
# 샬라샬라하다가 3
# shout 3
# out 3
# Pump 3
# up 12
# the 24
# power 38
# 난 3
# 자유로워 3
# yap, 3
# yap 3
# Do 3
# not 3
# waste 3
# your 3
# time 3
# yea 3
# it’s 3
# gotta 3
# be 3
# me 3
# Prove 3
# ‘em 3
# all 6
# wrong 3
# I’ve 5
# got 13
# all 6
# the 24
# receipts 3
# I 10
# got 13
# the 24
# power 38
# the 24
# power 38
# power 38
# up 12
# power 38
# 나는 3
# 나다워서 3
# 아름다워 3
# yep, 3
# yep 3
# 애들이 1
# 나보고 1
# 개꿀이라더군 1
# 댓글 1
# 리플 1
# 관종 1
# 걔들 1
# 입틀막고 1
# 2세대 1
# 한정품이 1
# 세기의 1
# 완성품 1
# (Like 1
# a 3
# Dragon 1
# fly) 1
# 누울 1
# 자리 1
# 글로 1
# 발명품 1
# Hi-Hey-How 1
# u 1
# doin’ 1
# My-my 1
# name 1
# is 3
# (Called) 1
# G 1
# to 3
# the 24
# D 1
# or 1
# ‘GOAT’ 1
# the 24
# livin’ 1
# legend 1
# King 1
# is 3
# still 1
# poppin’ 1
# (star) 1
# ’K‘- 1
# 다시 1
# I 10
# heard 1
# you’ve 1
# got 13
# the 24
# straight 1
# flush 1
# (Whateva) 1
# “He’s 1
# 4ever 1
# royal.” 1
# I 10
# don’t 2
# give 2
# a 3
# 쉬-잇 2
# 웃다 2
# 끝 2
# ‘돈’ 2
# 기부 2
# ‘억’ 2
# 씨-익 2
# 권력오남용 2
# 묻고 2
# 관용 2
# 천재 2
# 지병 2
# 불가항력 2
# Way 2
# too 2
# strong 2
# I’ve 5
# got 13
# that 2
# Now 3
# I 10
# got 13
# the 24
# power, 4
# The 7
# power 38
# power 38
# up 12
# power 38
# power 38
# The 7
# power 38
# up 12
# power 38
# power 38
# yet, 3
# yet 3
# 억까 3
# 짤 3
# 퍼다 3
# 샬라샬라하다가 3
# shout 3
# out 3
# Pump 3
# up 12
# the 24
# power 38
# 난 3
# 자유로워 3
# yap, 3
# yap 3
# Do 3
# not 3
# waste 3
# your 3
# time 3
# yea 3
# it’s 3
# gotta 3
# be 3
# me 3
# Prove 3
# ‘em 3
# all 6
# wrong 3
# I’ve 5
# got 13
# all 6
# the 24
# receipts 3
# I 10
# got 13
# the 24
# power 38
# the 24
# power 38
# power 38
# up 12
# power 38
# 나는 3
# 나다워서 3
# 아름다워 3
# yep, 3
# yep 3
# 일당백 1
# ‘지뢰밭’ 1
# 본업이(Born 1
# to 3
# be) 1
# ‘BANG’ 1
# Nothin’ 1
# U 1
# ain’t 1
# know 1
# But 2
# A 1
# ‘G’ 1
# Thang 1
# But 2
# my 2
# girl, 1
# Y’all 1
# my 2
# brothers 1
# (Who 1
# run 1
# the 24
# world?) 1
# The 7
# world 1
# is 3
# yours 1
# 동서남북 1
# Asia 1
# (미르시여) 1
# Europe 1
# to 3
# Australia 1
# (나르샤) 1
# Africa 1
# 2 1
# America 1
# (어서옵쇼) 1
# Started 1
# from 1
# the 24
# bottom 1
# ‘Now, 1
# Here’ 1
# (아리랑) 1
# I 10
# don’t 2
# give 2
# a 3
# 쉬-잇 2
# 웃다 2
# 끝 2
# ‘돈’ 2
# 기부 2
# ‘억’ 2
# 씨-익 2
# 권력오남용 2
# 묻고 2
# 관용 2
# 천재 2
# 지병 2
# 불가항력 2
# Way 2
# too 2
# strong 2
# I’ve 5
# got 13
# that 2
# Now 3
# I 10
# got 13
# the 24
# power, 4
# The 7
# power 38
# power 38
# up 12
# power 38
# power 38
# The 7
# power 38
# up 12
# power 38
# power 38
# yet, 3
# yet 3
# 억까 3
# 짤 3
# 퍼다 3
# 샬라샬라하다가 3
# shout 3
# out 3
# Pump 3
# up 12
# the 24
# power 38
# 난 3
# 자유로워 3
# yap, 3
# yap 3
# Do 3
# not 3
# waste 3
# your 3
# time 3
# yea 3
# it’s 3
# gotta 3
# be 3
# me 3
# Prove 3
# ‘em 3
# all 6
# wrong 3
# I’ve 5
# got 13
# all 6
# the 24
# receipts 3
# I 10
# got 13
# the 24
# power 38
# the 24
# power 38
# power 38
# up 12
# power 38
# 나는 3
# 나다워서 3
# 아름다워 3
# yep, 3
# yep 3
# I 10
# got 13
# the 24
# power 38
# the 24
# power 38
# power, 4
# “88 1
# 날아.” 1
